# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import soccerdata as sd
import socceraction.spadl as spadl
import socceraction.xthreat as xthreat
import pandas as pd
from socceraction.data.opta import OptaLoader

# %%
# Setup a scraper for the 2024/2025 Premier League season
# ws = sd.WhoScored(leagues="ENG-Premier League", seasons=2024)
# # Scrape all games and return a OptaLoader object
# api = ws.read_events(output_fmt='loader') #não está na biblioteca / não deve funcionar

# %%
api2 = OptaLoader(root="data/WhoScored/events/ENG-Premier League_2024", parser="whoscored")

# %%
# df_comp = api2.competitions()
# df_comp.head()
# df_test_jogo = api2.events(1821049)
# df_test_jogo.head()

# %%
# 1. Load a set of actions to train the model on
df_games = api2.games(competition_id=1, season_id=1)
dataset = [
    {
        **game,
        'actions': spadl.opta.convert_to_actions(
            events=api2.events(game['game_id']),
            home_team_id=game['home_team_id']
        )
    }
    for game in df_games.to_dict(orient='records')
]

# %%
# 2. Convert direction of play + add names
df_actions_ltr = pd.concat([
  spadl.play_left_to_right(game['actions'], game['home_team_id'])
  for game in dataset
])
df_actions_ltr = spadl.add_names(df_actions_ltr)

# %%
before = len(df_actions_ltr)

df_actions_ltr = (
    df_actions_ltr
    .replace([float("inf"), float("-inf")], pd.NA)  # turn inf into NaN
    .dropna()  # drop all NaN rows
)

after = len(df_actions_ltr)

print(f"Dropped rows: {before - after}")
print(f"Remaining rows: {after}")
# Out:
# Dropped rows: 126130
# Remaining rows: 478845

# %%
# 3. Train xT model with 16 x 12 grid
xTModel = xthreat.ExpectedThreat(l=16, w=12)
xTModel.fit(df_actions_ltr)
# Out:
# # iterations:  30

# %%
# 4. Rate ball-progressing actions
# xT should only be used to value actions that move the ball
# and that keep the current team in possession of the ball
df_mov_actions = xthreat.get_successful_move_actions(df_actions_ltr)
df_mov_actions["xT_value"] = xTModel.rate(df_mov_actions)

# %%
df_mov_actions.head()
# Out:
#     game_id  original_event_id  period_id  time_seconds  team_id  player_id  \
# 0   1821049       2.709313e+09          1           0.0      170   243254.0
# 1   1821049       2.709313e+09          1           1.0      170   297395.0
# 3   1821049       2.709313e+09          1           7.0      170   300359.0
# 7   1821049       2.709313e+09          1          12.0       32   460260.0
# 14  1821049       2.709314e+09          1          61.0      170   243254.0
#
#     start_x   end_x  start_y   end_y  type_id  result_id  bodypart_id  \
# 0    52.395  41.160   33.932  31.756        0          1            0
# 1    41.160  25.410   31.756  24.956        0          1            0
# 3    32.025  68.985   14.008   7.208        0          1            0
# 7    39.480  46.200   66.912  65.824        0          1            0
# 14   71.820  70.455   20.672  29.308        0          1            1
#
#     action_id type_name result_name bodypart_name  xT_value
# 0           0      pass     success          foot -0.000879
# 1           1      pass     success          foot -0.002196
# 3           3      pass     success          foot  0.007075
# 7           7      pass     success          foot  0.000910
# 14         14      pass     success          head  0.000665

# %%
df_sum_xt = (
    df_mov_actions
    .groupby(["team_id", "player_id"])["xT_value"]
    .sum()
    .reset_index()
    .sort_values(by="xT_value", ascending=False)
)
df_sum_xt.head()
# Out:
#      team_id  player_id  xT_value
# 172       26   108226.0  7.532105
# 178       26   318871.0  7.218087
# 440      170   306581.0  6.086037
# 432      170   136824.0  5.986651
# 235       30   362352.0  5.349771

# %%
df_games = api2.games(1, 1)
game_ids = df_games['game_id'].unique()

# --- Teams ---
team_list = []
for gid in game_ids:
    teams_df = api2.teams(gid)  # returns dataframe with team_id, team_name
    team_list.append(teams_df)

df_teams = pd.concat(team_list).drop_duplicates(subset="team_id")

# --- Players ---
player_list = []
for gid in game_ids:
    players_df = api2.players(gid)  # returns player_id, player_name, minutes_played
    player_list.append(players_df)

df_players = pd.concat(player_list)

# %%
# --- Step 1: Summarize players ---
# Sum minutes played per player across all games
df_minutes = df_players.groupby("player_id")["minutes_played"].sum().reset_index()

# Keep player names (drop duplicates)
# df_player_names = df_players[["player_id", "player_name"]].drop_duplicates()
df_player_names = (
    df_players
    .sort_values("game_id")  # optional, to take first starting_position chronologically
    .groupby("player_id")
    .agg(
        player_name=("player_name", "first"),
        starting_position=("starting_position", "first")
    )
    .reset_index()
)

# Merge names + total minutes
df_players_summary = df_player_names.merge(df_minutes, on="player_id", how="left")

# --- Step 2: Merge team names ---
df_sum_xt = df_sum_xt.merge(df_teams, on="team_id", how="left")

df_sum_xt = df_sum_xt.merge(df_players_summary, on="player_id", how="left")
df_sum_xt = df_sum_xt[["team_name", "player_name", "starting_position", "xT_value", "minutes_played"]]

# Check results
df_sum_xt.head(50)
# Out:
#             team_name             player_name starting_position  xT_value  \
# 0           Liverpool           Mohamed Salah               AMR  7.532105
# 1           Liverpool  Trent Alexander-Arnold                DR  7.218087
# 2              Fulham        Antonee Robinson                DL  6.086037
# 3              Fulham              Alex Iwobi               AML  5.986651
# 4           Tottenham             Pedro Porro                DR  5.349771
# 5           Newcastle            Jacob Murphy               FWR  5.336440
# 6           Brentford            Bryan Mbeumo               FWR  5.281786
# 7             Man Utd         Bruno Fernandes                FW  5.239470
# 8           Brentford        Mikkel Damsgaard               Sub  4.978687
# 9             Chelsea             Cole Palmer               AMR  4.696800
# 10          Brentford      Keane Lewis-Potter               Sub  4.672981
# 11             Fulham            Adama Traoré               AMR  4.636538
# 12     Crystal Palace         Tyrick Mitchell               DML  4.361442
# 13          Newcastle          Anthony Gordon               FWL  4.151624
# 14     Crystal Palace            Ismaïla Sarr               Sub  4.118607
# 15          Liverpool          Andy Robertson                DL  4.092386
# 16           Man City         Kevin De Bruyne               AMC  4.065896
# 17           West Ham            Jarrod Bowen                MR  4.052782
# 18          Newcastle           Harvey Barnes               Sub  3.963206
# 19             Wolves           Matheus Cunha               Sub  3.913206
# 20            Everton       Vitalii Mykolenko                DL  3.799825
# 21           West Ham       Aaron Wan-Bissaka               Sub  3.789236
# 22           Brighton      Jan Paul van Hecke                DC  3.764498
# 23          Newcastle         Bruno Guimarães                MC  3.764477
# 24            Arsenal             Bukayo Saka               FWR  3.753207
# 25            Chelsea              Pedro Neto               Sub  3.664075
# 26            Everton            Ashley Young                DR  3.642468
# 27        Bournemouth            Milos Kerkez                DL  3.587450
# 28          Tottenham          James Maddison                MC  3.475839
# 29           Man City                 Savinho               AML  3.435035
# 30          Liverpool         Virgil van Dijk                DC  3.381689
# 31            Chelsea          Enzo Fernández               AMC  3.325784
# 32        Bournemouth          Dango Ouattara               AMR  3.291319
# 33           Brighton          Yankuba Minteh               AMR  3.284662
# 34            Arsenal        Leandro Trossard               Sub  3.284364
# 35            Ipswich              Leif Davis                DL  3.255708
# 36        Aston Villa             Lucas Digne                DL  3.230968
# 37        Bournemouth         Antoine Semenyo                FW  3.209064
# 38          Tottenham           Son Heung-Min               FWL  3.208736
# 39        Aston Villa         Youri Tielemans               DMC  3.163247
# 40        Aston Villa           Morgan Rogers               AMC  3.163235
# 41           Man City             Jérémy Doku               AMR  3.139480
# 42           Brighton            Kaoru Mitoma               AML  3.128088
# 43          Newcastle              Lewis Hall                DL  3.096531
# 44  Nottingham Forest                Ola Aina                DL  3.090015
# 45  Nottingham Forest      Morgan Gibbs-White               AMC  3.086105
# 46            Arsenal      Gabriel Martinelli               FWL  3.069241
# 47           Brighton        Pervis Estupiñán               Sub  3.034084
# 48            Arsenal         Martin Ødegaard                MC  3.020520
# 49          Liverpool               Luis Díaz               AML  2.999563
#
#     minutes_played
# 0             3715
# 1             2583
# 2             3502
# 3             3209
# 4             2922
# 5             2547
# 6             3663
# 7             3323
# 8             3041
# 9             3534
# 10            3274
# 11            1975
# 12            3259
# 13            2638
# 14            2884
# 15            2715
# 16            1849
# 17            3269
# 18            1983
# 19            2890
# 20            3404
# 21            3509
# 22            3344
# 23            3575
# 24            1891
# 25            2540
# 26            2098
# 27            3687
# 28            1982
# 29            1917
# 30            3704
# 31            3274
# 32            2228
# 33            2016
# 34            2815
# 35            3026
# 36            2601
# 37            3521
# 38            2320
# 39            3359
# 40            3411
# 41            1666
# 42            2879
# 43            2418
# 44            3322
# 45            3017
# 46            2491
# 47            2695
# 48            2524
# 49            2609
